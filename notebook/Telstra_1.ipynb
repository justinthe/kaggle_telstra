# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
event_type = pd.read_csv('telstra/event_type.csv', error_bad_lines=False)
log_feature = pd.read_csv('telstra/log_feature.csv')
resource_type = pd.read_csv('telstra/resource_type.csv', error_bad_lines=False)
severity_type = pd.read_csv('telstra/severity_type.csv')
train = pd.read_csv('telstra/train.csv')
holdout = pd.read_csv('telstra/test.csv')
# Out:
# b'Skipping line 31173: expected 2 fields, saw 3\nSkipping line 31174: expected 2 fields, saw 3\nSkipping line 31175: expected 2 fields, saw 3\nSkipping line 31176: expected 2 fields, saw 3\nSkipping line 31177: expected 2 fields, saw 3\nSkipping line 31178: expected 2 fields, saw 3\nSkipping line 31179: expected 2 fields, saw 3\nSkipping line 31180: expected 2 fields, saw 3\nSkipping line 31181: expected 2 fields, saw 3\nSkipping line 31182: expected 2 fields, saw 3\nSkipping line 31183: expected 2 fields, saw 3\nSkipping line 31184: expected 2 fields, saw 3\nSkipping line 31185: expected 2 fields, saw 3\nSkipping line 31186: expected 2 fields, saw 3\nSkipping line 31187: expected 2 fields, saw 3\nSkipping line 31188: expected 2 fields, saw 3\nSkipping line 31189: expected 2 fields, saw 3\nSkipping line 31190: expected 2 fields, saw 3\nSkipping line 31191: expected 2 fields, saw 3\nSkipping line 31192: expected 2 fields, saw 3\nSkipping line 31193: expected 2 fields, saw 3\nSkipping 
# ...

# %%
print(event_type.shape)
event_type.head(3)
# Out:
# (31171, 2)
#      id     event_type
# 0  6597  event_type 11
# 1  8011  event_type 15
# 2  2597  event_type 15

# %%
print(log_feature.shape)
log_feature.head(3)
# Out:
# (58671, 3)
#      id log_feature  volume
# 0  6597  feature 68       6
# 1  8011  feature 68       7
# 2  2597  feature 68       1

# %%
print(resource_type.shape)
resource_type.head(3)
# Out:
# (21077, 2)
#      id    resource_type
# 0  6597  resource_type 8
# 1  8011  resource_type 8
# 2  2597  resource_type 8

# %%
print(severity_type.shape)
severity_type.head(3)
# Out:
# (18552, 2)
#      id    severity_type
# 0  6597  severity_type 2
# 1  8011  severity_type 2
# 2  2597  severity_type 2

# %%
train.head(3)
# Out:
#       id      location  fault_severity
# 0  14121  location 118               1
# 1   9320   location 91               0
# 2  14394  location 152               1

# %%
holdout.head(3)
# Out:
#       id      location
# 0  11066  location 481
# 1  18000  location 962
# 2  16964  location 491

# %%
severity_resource = pd.merge(severity_type, resource_type, how='outer', left_on="id", right_on='id')

# %%
# somehow we got an error when joining event and log. turns out because 1 id of event is not numeric
evtype = event_type['id']

# %%
evtype[evtype.where(evtype.str.isnumeric()).isnull()]
# Out:
# 31170    _type 50
# Name: id, dtype: object

# %%
evtype2[evtype2.isnull()]
# Out:
# 31170    NaN
# Name: id, dtype: object

# %%
#event_type['id'][31170]
event_type['id'] = event_type['id'].drop(index=31170)
event_type['id'] = event_type['id'].dropna()

# %%
event_type['id'] = event_type['id'].astype(np.int64)
event_log = pd.merge(event_type, log_feature, how='outer', left_on='id', right_on='id')
#event_type.info()
#log_feature.info()


#np.issubdtype(event_type['id'].dtype, np.number)
# Out:
# /home/user/anaconda3/envs/spatial/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
event_log
# Out:
#            id     event_type  log_feature  volume
# 0        6597  event_type 11   feature 68       6
# 1        8011  event_type 15   feature 68       7
# 2        2597  event_type 15   feature 68       1
# 3        5022  event_type 15  feature 172       2
# 4        5022  event_type 15   feature 56       1
# 5        5022  event_type 15  feature 193       4
# 6        5022  event_type 15   feature 71       3
# 7        5022  event_type 11  feature 172       2
# 8        5022  event_type 11   feature 56       1
# 9        5022  event_type 11  feature 193       4
# 10       5022  event_type 11   feature 71       3
# 11       6852  event_type 11  feature 201       2
# 12       6852  event_type 11   feature 56       1
# 13       6852  event_type 11   feature 80       2
# 14       6852  event_type 15  feature 201       2
# 15       6852  event_type 15   feature 56       1
# 16       6852  event_type 15   feature 80       2
# 17       5611  event_type 15   feature 80       2
# ...

# %%
data = pd.merge(severity_resource, event_log, how='outer', left_on='id', right_on='id')

# %%
data.head(3)
# Out:
#      id    severity_type    resource_type     event_type log_feature  volume
# 0  6597  severity_type 2  resource_type 8  event_type 11  feature 68       6
# 1  8011  severity_type 2  resource_type 8  event_type 15  feature 68       7
# 2  2597  severity_type 2  resource_type 8  event_type 15  feature 68       1

# %%
train.head(3)
# Out:
#       id      location  fault_severity
# 0  14121  location 118               1
# 1   9320   location 91               0
# 2  14394  location 152               1

# %%
data[data['id'] == 9320]
# Out:
#           id    severity_type    resource_type     event_type  log_feature  \
# 137030  9320  severity_type 2  resource_type 2  event_type 34  feature 315
# 137031  9320  severity_type 2  resource_type 2  event_type 34  feature 235
# 137032  9320  severity_type 2  resource_type 2  event_type 35  feature 315
# 137033  9320  severity_type 2  resource_type 2  event_type 35  feature 235
#
#         volume
# 137030     200
# 137031     116
# 137032     200
# 137033     116

# %%
train[train['id'] == 9320]
# Out:
#      id     location  fault_severity
# 1  9320  location 91               0

# %%
cls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-4b94d9d35cf3> in <module>()
# ----> 1 cls
#
# NameError: name 'cls' is not defined
